# %% [markdown]
# **How much time did you work on this assignment and how often did you
# meet?**
#
# Insgesamt sind ca. 40-50 Stunden in dieses Assignment geflossen. Dafür haben wir uns nach den Vorlesungen unter der Woche in der Hochschule zusammengesetzt(4mal) und am Wochenende haben wir telefoniert oder über WhatsApp kommuniziert.
#
# ---
#
# **Did you use Google Colab or Anaconda?**
#
# Wir haben Google Colab verwendet. Der Editor von Google Colab ist deutlich moderner und bietet nochmal mehr Funktionen als das lokale Juiper Notebook in Anaconda. Ebenfalls war es angenehm für Aufgaben wie die G, wenn man die verschiedenen Solver auf Google Servern laufen lassen kann statt auf dem eigenen Rechner. Autovervollständigung oder das automatische Installieren aller Python Pakete ist ebenfalls hilfreich.
#
# ---
#
# **What was your favourite excercise? Why?**
#
# Aufgabe D, da man hier das Datenset wirklich verstanden hat.
#
# ---
#
# **What excercise did you like least? Why?**
#
# Aufgabe E, da man hier viel Arbeit hatte aber kaum etwas neues gelernt hat.
# Wenn man das Datenset einmal richtig formatiert hat war die meiste Arbeit geschafft.
#
# ---
#
# Man hat im Assignment viel lernen können, jedoch war der Einstieg sehr schwer. Die Theorie wurde in der Vorlesung zwar gut erklärt und theoretisch hätte man die Aufgaben schnell lösen können, jedoch ist die technische Umsetzung bisschen zu kurz gekommen. Der "Spaß"-Faktor Dinge auszuprobieren ist völlig in den Hintergrund gerutscht und man hat nur versucht das Assignment in der Zeit zu schaffen.
#
# Da nur einer von uns Vorkenntnisse in Python hatte, musste die andere Person Python "lernen" und konnte nicht wirklich an den Aufgaben mitarbeiten. Somit war die Aufgabenverteilung und der Zeitaufwand nicht wirklich ausgeglichen. Ein gegenseitiger Wissenaustausch und gemeinsames Lernen war somit schwer möglich.
#
# Vorschlag für das nächste mal: Mehr Zeit für den Einstieg in Python, Anaconda / Jupiter Notebook und einarbeiten ins Thema geben. Für viele sind dies alles komplett neue Themen.
